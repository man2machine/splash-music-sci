# %%
from sygyt_lib.demos import *

# %%
run_signal_fft_demo()
# Out:
# interactive(children=(Dropdown(description='sig_type', options=('sine', 'square', 'sawtooth'), value='sine'), …
# <function sygyt_lib.demos.run_signal_fft_demo.<locals>.demo(sig_type, num_harmonics_filter)>

# %%
run_instruments_harmonic_demo()
# Out:
# interactive(children=(Dropdown(description='instrument', options=('oboe', 'sax', 'trumpet', 'violin'), value='…
# <function sygyt_lib.demos.run_instruments_harmonic_demo.<locals>.demo(instrument)>

# %%
run_play_fantasia()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
run_show_fantasia_cqt()

# %%
run_note_detection_demo()

# %%
run_play_shazam_songs()

# %%
run_shazam_demo()
